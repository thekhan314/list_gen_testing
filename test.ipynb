# %%
import time
import pandas as pd

# Define your functions to be compared
def list_method(lim):
    # Replace this with the actual code of your first function
    out = list(range(lim))

def list_comp(lim):
    # Replace this with the actual code of your second function
    out = [i for i in range(lim)]

def compare_time(list_size):

    execution_time_function1 = []
    execution_time_function2 = []

    while x <= 30:
        start_time = time.time()
        list_method(list_size)
        end_time = time.time()
        execution_time_function1 = end_time - start_time

        # Measure the execution time of function2
        start_time = time.time()
        list_comp(list_size)
        end_time = time.time()
        execution_time_function2 = end_time - start_time



    output = {
        "list_comp": execution_time_function1,
        "list_method":execution_time_function2,
        "perc_diff": ((execution_time_function1 - execution_time_function2)/execution_time_function1) * 100
    }

    return output

def run_test(num_zeros):

    results = []
    expon = 1

    while expon <= num_zeros:
        x = 10 ** expon
        expon += 1

        test_row = compare_time(x)
        test_row['list_size'] = x
        results.append(test_row)

    df = pd.DataFrame.from_records(results,index = 'list_size').sort_index()
    

    df[['list_comp','list_method']].plot()

    return df

run_test(8)
# Out:
#            list_comp  list_method   perc_diff
# list_size
# 10          0.000008     0.000004   47.058824
# 100         0.000003     0.000007 -107.142857
# 1000        0.000020     0.000045 -126.506024
# 10000       0.000190     0.000422 -122.613065
# 100000      0.005237     0.010740 -105.076027
# 1000000     0.090058     0.117538  -30.513594
# 10000000    0.833419     1.311128  -57.319143
# 100000000   9.315253    12.629371  -35.577326

# %%
import timeit

# %%
import time
import timeit
import pandas as pd

# Define your functions to be compared
def list_method(lim):
    # Replace this with the actual code of your first function
    out = list(range(lim))

def list_comp(lim):
    # Replace this with the actual code of your second function
    out = [i for i in range(lim)]

def compare_time(list_size):

    execution_time_function1 = timeit.timeit('list_method({})'.format(list_size),globals=globals(),number = 3)

    # Measure the execution time of function2
    execution_time_function2 = timeit.timeit('list_comp({})'.format(list_size),globals=globals(),number = 3)


    output = {
        "list_comp": execution_time_function1,
        "list_method":execution_time_function2,
        "perc_diff": ((execution_time_function1 - execution_time_function2)/execution_time_function1) * 100
    }

    return output

def run_test(num_zeros):

    results = []
    expon = 1

    while expon <= num_zeros:
        x = 10 ** expon
        expon += 1

        test_row = compare_time(x)
        test_row['list_size'] = x
        results.append(test_row)

    df = pd.DataFrame.from_records(results,index = 'list_size').sort_index()
    

    df[['list_comp','list_method']].plot()

    return df

run_test(7)
# Out:
#            list_comp  list_method  perc_diff
# list_size
# 10          0.000011     0.000020 -91.509471
# 100         0.000019     0.000015  18.181812
# 1000        0.000106     0.000122 -14.393227
# 10000       0.002291     0.004445 -94.041383
# 100000      0.024523     0.020162  17.782010
# 1000000     0.229258     0.266454 -16.224537
# 10000000    3.005823     3.806938 -26.652107

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 7.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /home/umark/.local/lib/python3.10/site-packages (from matplotlib) (1.26.2)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 KB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /home/umark/.local/lib/python3.10/site-packages (from matplotlib) (23.1)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.44.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 9.8 MB/s eta 0:00:00:00:0100:01
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/umark/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.44.3 kiwisolver-1.4.5 matplotlib-3.8.2
